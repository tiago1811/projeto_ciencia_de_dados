# %% [markdown]
# # Trabalho 3° Unidade

# %% [markdown]
# ## Fluxo Escolar no Estado de São Paulo (SP)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ## CARREGAR O ARQUIVO

# %%
file_path = 'escolas.mod.csv'
data = pd.read_csv(file_path)

# %% [markdown]
# ## INSPECIONAR OS DADOS

# %%
print(data.columns)
print(data.dtypes)
# Out:
# Index(['ano', 'sigla_uf', 'rede', 'diretoria', 'id_municipio', 'id_escola',
#        'id_escola_sp', 'codigo_tipo_escola', 'prop_aprovados_anos_inciais_ef',
#        'prop_reprovados_anos_iniciais_ef', 'prop_abandono_anos_iniciais_ef',
#        'prop_aprovados_anos_finais_ef', 'prop_reprovados_anos_finais_ef',
#        'prop_abandono_anos_finais_ef', 'prop_aprovados_em',
#        'prop_reprovados_em', 'prop_abandono_em'],
#       dtype='object')
# ano                                   int64
# sigla_uf                             object
# rede                                 object
# diretoria                            object
# id_municipio                        float64
# id_escola                             int64
# id_escola_sp                          int64
# codigo_tipo_escola                  float64
# prop_aprovados_anos_inciais_ef      float64
# prop_reprovados_anos_iniciais_ef    float64
# prop_abandono_anos_iniciais_ef      float64
# prop_aprovados_anos_finais_ef       float64
# prop_reprovados_anos_finais_ef      float64
# prop_abandono_anos_finais_ef        float64
# prop_aprovados_em                   float64
# prop_reprovados_em                  float64
# prop_abandono_em                    float64
# dtype: object

# %% [markdown]
# ## VISUALIZAR O CONTEÚDO DE CADA COLUNA

# %%
for column in data.columns:
    print(f"Coluna: {column}")
    print(data[column].head(), "\n")
# Out:
# Coluna: ano
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2012
# Name: ano, dtype: int64
#
# Coluna: sigla_uf
# 0    SP
# 1    SP
# 2    SP
# 3    SP
# 4    SP
# Name: sigla_uf, dtype: object
#
# Coluna: rede
# 0    estadual
# 1    estadual
# 2    estadual
# 3    estadual
# 4         NaN
# Name: rede, dtype: object
#
# Coluna: diretoria
# 0                 SUZANO
# 1                 SANTOS
# 2                 SANTOS
# 3               BOTUCATU
# 4    SAO JOSE DOS CAMPOS
# Name: diretoria, dtype: object
#
# Coluna: id_municipio
# 0    3552502.0
# 1    3548500.0
# 2    3548500.0
# 3    3506904.0
# 4    3549904.0
# Name: id_municipio, dtype: float64
#
# Coluna: id_escola
# 0    35906300
# 1    35909816
# 2    35038805
# 3    35014801
# 4    35902548
# Name: id_escola, dtype: int64
#
# Coluna: id_escola_sp
# 0    906300
# 1    909816
# 2     38805
# 3     14801
# 4    902548
# Name: id_escola_sp, dtype: int64
#
# Coluna: codigo_tipo_escola
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: codigo_tipo_escola, dtype: float64
#
# Coluna: prop_aprovados_anos_inciais_ef
# 0    96.460175
# 1    96.296295
# 2    93.430656
# 3    93.548386
# 4    96.990000
# Name: prop_aprovados_anos_inciais_ef, dtype: float64
#
# Coluna: prop_reprovados_anos_iniciais_ef
# 0    2.654867
# 1    1.851852
# 2    5.839416
# 3    3.225806
# 4    2.800000
# Name: prop_reprovados_anos_iniciais_ef, dtype: float64
#
# Coluna: prop_abandono_anos_iniciais_ef
# 0    0.884956
# 1    1.851852
# 2    0.729927
# 3    3.225806
# 4    0.220000
# Name: prop_abandono_anos_iniciais_ef, dtype: float64
#
# Coluna: prop_aprovados_anos_finais_ef
# 0    92.708336
# 1    91.366905
# 2    86.082474
# 3    88.888886
# 4    93.240000
# Name: prop_aprovados_anos_finais_ef, dtype: float64
#
# Coluna: prop_reprovados_anos_finais_ef
# 0     3.125000
# 1     3.597122
# 2    13.402061
# 3     6.060606
# 4     5.370000
# Name: prop_reprovados_anos_finais_ef, dtype: float64
#
# Coluna: prop_abandono_anos_finais_ef
# 0    4.166667
# 1    5.035971
# 2    0.515464
# 3    5.050505
# 4    1.390000
# Name: prop_abandono_anos_finais_ef, dtype: float64
#
# Coluna: prop_aprovados_em
# 0    89.655174
# 1    75.916229
# 2    71.608040
# 3    86.257309
# 4    86.590000
# Name: prop_aprovados_em, dtype: float64
#
# Coluna: prop_reprovados_em
# 0     6.896552
# 1    10.994764
# 2    27.386934
# 3     1.754386
# 4    10.370000
# Name: prop_reprovados_em, dtype: float64
#
# Coluna: prop_abandono_em
# 0     3.448276
# 1    13.089005
# 2     1.005025
# 3    11.988304
# 4          NaN
# Name: prop_abandono_em, dtype: float64

# %% [markdown]
# ## INSPECIONAR OS REGISTROS DA PLANILHA

# %%
data.head()
# Out:
#     ano sigla_uf      rede            diretoria  id_municipio  id_escola  \
# 0  2011       SP  estadual               SUZANO     3552502.0   35906300
# 1  2011       SP  estadual               SANTOS     3548500.0   35909816
# 2  2011       SP  estadual               SANTOS     3548500.0   35038805
# 3  2011       SP  estadual             BOTUCATU     3506904.0   35014801
# 4  2012       SP       NaN  SAO JOSE DOS CAMPOS     3549904.0   35902548
#
#    id_escola_sp  codigo_tipo_escola  prop_aprovados_anos_inciais_ef  \
# 0        906300                 NaN                       96.460175
# 1        909816                 NaN                       96.296295
# 2         38805                 NaN                       93.430656
# 3         14801                 NaN                       93.548386
# 4        902548                 NaN                       96.990000
#
#    prop_reprovados_anos_iniciais_ef  prop_abandono_anos_iniciais_ef  \
# 0                          2.654867                        0.884956
# 1                          1.851852                        1.851852
# 2                          5.839416                        0.729927
# 3                          3.225806                        3.225806
# 4                          2.800000                        0.220000
#
#    prop_aprovados_anos_finais_ef  prop_reprovados_anos_finais_ef  \
# 0                      92.708336                        3.125000
# 1                      91.366905                        3.597122
# 2                      86.082474                       13.402061
# 3                      88.888886                        6.060606
# 4                      93.240000                        5.370000
#
#    prop_abandono_anos_finais_ef  prop_aprovados_em  prop_reprovados_em  \
# 0                      4.166667          89.655174            6.896552
# 1                      5.035971          75.916229           10.994764
# 2                      0.515464          71.608040           27.386934
# 3                      5.050505          86.257309            1.754386
# 4                      1.390000          86.590000           10.370000
#
#    prop_abandono_em
# 0          3.448276
# 1         13.089005
# 2          1.005025
# 3         11.988304
# 4               NaN

# %% [markdown]
# ## REMOVER LINHAS COM VALORES AUSENTES

# %%
data = data.dropna()

# %% [markdown]
# ## REMOVE OS VALORES ZEROS DAS COLUNAS

# %%
data = data.loc[~(data == 0).any(axis=1)]

# %% [markdown]
# ## CRIAR LISTA DE COLUNAS QUANTITAVAS E QUALITATIVAS

# %%
variable_types = {
    "Quantitativas": [
        "prop_aprovados_anos_inciais_ef", "prop_reprovados_anos_iniciais_ef", "prop_abandono_anos_iniciais_ef", "prop_aprovados_anos_finais_ef", "prop_reprovados_anos_finais_ef", "prop_abandono_anos_finais_ef"
    ],
    "Qualitativas": [
        "ano", "sigla_uf", "rede", "diretoria", "id_municipio", "id_escola", "id_escola_sp", "codigo_tipo_escola"
    ]
}

print("Quantitativas:", variable_types["Quantitativas"])
print("Qualitativas:", variable_types["Qualitativas"])
# Out:
# Quantitativas: ['prop_aprovados_anos_inciais_ef', 'prop_reprovados_anos_iniciais_ef', 'prop_abandono_anos_iniciais_ef', 'prop_aprovados_anos_finais_ef', 'prop_reprovados_anos_finais_ef', 'prop_abandono_anos_finais_ef']
# Qualitativas: ['ano', 'sigla_uf', 'rede', 'diretoria', 'id_municipio', 'id_escola', 'id_escola_sp', 'codigo_tipo_escola']

# %% [markdown]
# ## INICIANDO AS ESTATÍSTICAS

# %%
# Inicializando o dicionário de estatísticas
stats = {}

# Estatísticas para variáveis quantitativas
for column in variable_types["Quantitativas"]:
    stats[column] = {
        "média": data[column].mean(),
        "moda": data[column].mode().iloc[0] if not data[column].mode().empty else None,
        "mediana": data[column].median(),
        "variância": data[column].var(),
        "amplitude": data[column].max() - data[column].min(),
        "mínimo": data[column].min(),
        "máximo": data[column].max(),
        "valores_distintos": data[column].nunique(),
    }

# Estatísticas para variáveis qualitativas
for column in variable_types["Qualitativas"]:
    stats[column] = {
        "valores_distintos": data[column].nunique(),
        "moda": data[column].mode().iloc[0] if not data[column].mode().empty else None,
    }

# Convertendo para DataFrame para exibição
stats_df = pd.DataFrame(stats).T

# Exibindo o DataFrame com as estatísticas
stats_df
# Out:
#                                       média        moda mediana  variância  \
# prop_aprovados_anos_inciais_ef    96.337426       96.62   96.71   5.192715
# prop_reprovados_anos_iniciais_ef   2.482574        0.28    2.13   4.122843
# prop_abandono_anos_iniciais_ef         1.18        0.51   0.785   0.999947
# prop_aprovados_anos_finais_ef     87.113382       91.72  87.655  41.996776
# prop_reprovados_anos_finais_ef      9.18239        2.76    8.34  28.349167
# prop_abandono_anos_finais_ef       3.704228        0.37   2.875   8.265765
# ano                                     NaN      2015.0     NaN        NaN
# sigla_uf                                NaN          SP     NaN        NaN
# rede                                    NaN    estadual     NaN        NaN
# diretoria                               NaN       SUL 2     NaN        NaN
# id_municipio                            NaN   3550308.0     NaN        NaN
# id_escola                               NaN  35902901.0     NaN        NaN
# id_escola_sp                            NaN    902901.0     NaN        NaN
# codigo_tipo_escola                      NaN         8.0     NaN        NaN
#
#                                  amplitude mínimo máximo valores_distintos
# prop_aprovados_anos_inciais_ef       14.01   85.6  99.61             223.0
# prop_reprovados_anos_iniciais_ef     10.83   0.12  10.95             220.0
# prop_abandono_anos_iniciais_ef        4.82   0.11   4.93             169.0
# prop_aprovados_anos_finais_ef         39.0  59.49  98.49             256.0
# prop_reprovados_anos_finais_ef       29.12   0.63  29.75             251.0
# prop_abandono_anos_finais_ef         15.35   0.17  15.52             227.0
# ano                                    NaN    NaN    NaN               4.0
# sigla_uf                               NaN    NaN    NaN                 1
# rede                                   NaN    NaN    NaN                 1
# diretoria                              NaN    NaN    NaN                34
# id_municipio                           NaN    NaN    NaN              24.0
# id_escola                              NaN    NaN    NaN             174.0
# id_escola_sp                           NaN    NaN    NaN             174.0
# codigo_tipo_escola                     NaN    NaN    NaN               1.0

# %% [markdown]
# ## SALVANDO ESTATÍSTICAS

# %%
stats_df.to_csv('estatisticas.csv', index=True)

# %% [markdown]
# ## ÁNALISAR DISTRIBUIÇÕES

# %%
# Função para plotar histograma, gráfico de densidade e Q-Q plot
def plot_distribution(data, column):
    plt.figure(figsize=(12, 4))

    # Histograma
    plt.subplot(1, 3, 1)
    sns.histplot(data=data, x=column, kde=True)
    plt.title(f"Histograma de {column}")

    # Gráfico de densidade
    plt.subplot(1, 3, 2)
    sns.kdeplot(data=data, x=column)
    plt.title(f"Gráfico de Densidade de {column}")

    # Q-Q plot
    plt.subplot(1, 3, 3)
    stats.probplot(data[column], plot=plt.plot)
    plt.title(f"Q-Q Plot de {column}")

    plt.tight_layout()
    plt.show()

# Análise das variáveis quantitativas
for column in variable_types["Quantitativas"]:
    print(f"Análise da variável: {column}")
    print(stats_df.loc[column])

    # Plotar os gráficos
    plot_distribution(data, column)

    # Teste de normalidade de Shapiro-Wilk
    _, p_value = stats.shapiro(data[column])
    print(f"Teste de Shapiro-Wilk: p-valor = {p_value:.4f}")
    if p_value > 0.05:
        print("A distribuição é provavelmente normal.")
    else:
        print("A distribuição não é normal.")
    print("\n")
